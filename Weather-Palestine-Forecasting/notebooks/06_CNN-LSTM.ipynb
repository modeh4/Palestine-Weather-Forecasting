# %%
# =====================================================
#  CNN-LSTM WITH STATION EMBEDDING
# =====================================================

# =====================================================
# 1. IMPORT LIBRARIES
# =====================================================
import os
import random
import numpy as np
import tensorflow as tf

SEED = 42

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.keras.utils.set_random_seed(SEED)






import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dense, Embedding, GlobalMaxPooling1D, Concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping


# =====================================================
# 2. LOAD CLEANED DATASET
# =====================================================

df = pd.read_excel("/Users/mac/Desktop/enve/final enve/fill/final_filled_climate_cleaned.xlsx")

df["Date"] = pd.to_datetime(
    df["Date"],
    dayfirst=True,
    errors="coerce"
)


# =====================================================
# RAIN LOG TRANSFORMATION
# =====================================================

df["Rain_original"] = df["Rain"]

df["Rain"] = np.log1p(df["Rain"])

print(df[["Rain_original", "Rain"]].head())



df = df.dropna(subset=["Date"])
df = df.sort_values(["Station", "Date"]).reset_index(drop=True)

print(df.head())
print(df.isnull().sum())


# =====================================================
# 3. FINAL QUALITY CHECK
# =====================================================

print("Pressure zeros:", (df["PRESS"] == 0).sum())
print("Negative rain:", (df["Rain"] < 0).sum())
print("RH > 100:", (df["RH"] > 100).sum())
print("RH < 0:", (df["RH"] < 0).sum())
print("Negative sunshine:", (df["SUNSHINE"] < 0).sum())

print(df.describe())


# =====================================================
# 4. TEMPORAL FEATURES
# =====================================================

df["Month"] = df["Date"].dt.month
df["Week"] = df["Date"].dt.isocalendar().week.astype(int)
df["DayOfWeek"] = df["Date"].dt.dayofweek
df["Year"] = df["Date"].dt.year


# =====================================================
# 5. STATION ENCODING
# =====================================================

le = LabelEncoder()
df["Station_enc"] = le.fit_transform(df["Station"])

print("Station Encoding:")
for station, code in zip(le.classes_, range(len(le.classes_))):
    print(station, ":", code)


# =====================================================
# 6. DEFINE FEATURES AND TARGETS
# =====================================================

features = [
    "Temp",
    "RH",
    "Wind",
    "Rain",
    "PRESS",
    "SUNSHINE",
    "Month",
    "Week",
    "DayOfWeek"
]

targets = [
    "Temp",
    "RH",
    "Rain",
    "PRESS",
    "SUNSHINE"
]


# =====================================================
# 7. CHRONOLOGICAL SPLIT BEFORE SCALING
# =====================================================

train_df = df[df["Year"] <= 2022].copy()
val_df   = df[df["Year"] == 2023].copy()
test_df  = df[df["Year"] == 2024].copy()

print("Train:", train_df.shape)
print("Validation:", val_df.shape)
print("Test:", test_df.shape)


# =====================================================
# 8. SCALE DATA
# =====================================================

X_scaler = MinMaxScaler()
Y_scaler = MinMaxScaler()

X_scaler.fit(train_df[features])
Y_scaler.fit(train_df[targets])

train_X = X_scaler.transform(train_df[features])
val_X   = X_scaler.transform(val_df[features])
test_X  = X_scaler.transform(test_df[features])

train_Y = Y_scaler.transform(train_df[targets])
val_Y   = Y_scaler.transform(val_df[targets])
test_Y  = Y_scaler.transform(test_df[targets])

train_station = train_df["Station_enc"].values
val_station   = val_df["Station_enc"].values
test_station  = test_df["Station_enc"].values


# =====================================================
# 9. CREATE 30-DAY SEQUENCES
# =====================================================

SEQ_LEN = 30

def create_sequences(X, Y, station_ids, dates, seq_len=30):
    X_seq = []
    S_seq = []
    Y_seq = []
    D_seq = []

    for station in np.unique(station_ids):
        idx = np.where(station_ids == station)[0]

        X_station = X[idx]
        Y_station = Y[idx]
        dates_station = dates.iloc[idx].reset_index(drop=True)

        for i in range(len(X_station) - seq_len):
            X_seq.append(X_station[i:i + seq_len])
            S_seq.append(station)
            Y_seq.append(Y_station[i + seq_len])
            D_seq.append(dates_station.iloc[i + seq_len])

    return np.array(X_seq), np.array(S_seq), np.array(Y_seq), np.array(D_seq)


X_train, S_train, y_train, d_train = create_sequences(
    train_X, train_Y, train_station, train_df["Date"], SEQ_LEN
)

X_val, S_val, y_val, d_val = create_sequences(
    val_X, val_Y, val_station, val_df["Date"], SEQ_LEN
)

X_test, S_test, y_test, d_test = create_sequences(
    test_X, test_Y, test_station, test_df["Date"], SEQ_LEN
)

print("X_train:", X_train.shape)
print("S_train:", S_train.shape)
print("y_train:", y_train.shape)

print("X_val:", X_val.shape)
print("X_test:", X_test.shape)


# =====================================================
# 10. BUILD CNN-LSTM WITH STATION EMBEDDING
# =====================================================

num_features = X_train.shape[2]
num_targets = y_train.shape[1]
num_stations = df["Station_enc"].nunique()

seq_input = Input(shape=(SEQ_LEN, num_features), name="sequence_input")

x = Conv1D(
    filters=64,
    kernel_size=3,
    activation="relu",
    padding="valid"
)(seq_input)

x = LSTM(
    units=64,
    return_sequences=False
)(x)

station_input = Input(shape=(1,), name="station_input")

s = Embedding(
    input_dim=num_stations,
    output_dim=4,
    name="station_embedding"
)(station_input)

s = GlobalMaxPooling1D()(s)

combined = Concatenate()([x, s])

z = Dense(64, activation="relu")(combined)
z = Dropout(0.2)(z)

output = Dense(num_targets, activation="linear")(z)

model = Model(
    inputs=[seq_input, station_input],
    outputs=output
)

model.compile(
    optimizer="adam",
    loss="mse",
    metrics=["mae"]
)

model.summary()


# =====================================================
# 11. TRAIN MODEL
# =====================================================

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True
)

#history = model.fit(
   # [X_train, S_train],
    #y_train,
    #validation_data=([X_val, S_val], y_val),
   #epochs=100,
   # batch_size=32,
  #  callbacks=[early_stop],
 #   verbose=1
#)

tf.keras.utils.set_random_seed(42)

history = model.fit(
    [X_train, S_train],
    y_train,
    validation_data=([X_val, S_val], y_val),
    epochs=100,
    batch_size=32,
    callbacks=[early_stop],
    shuffle=True,
    verbose=1
)

# =====================================================
# 12. PLOT TRAINING CURVE
# =====================================================

plt.figure(figsize=(8, 5))
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)
plt.show()


# =====================================================
# 13. PREDICTION
# =====================================================

y_pred_scaled = model.predict([X_test, S_test])

y_pred = Y_scaler.inverse_transform(y_pred_scaled)
y_true = Y_scaler.inverse_transform(y_test)

rain_idx = targets.index("Rain")

#y_pred[:, rain_idx] = np.expm1(y_pred[:, rain_idx])
#y_true[:, rain_idx] = np.expm1(y_true[:, rain_idx])
max_log_rain = np.nanmax(y_true[:, rain_idx])

y_pred[:, rain_idx] = np.clip(y_pred[:, rain_idx], 0, max_log_rain)
y_true[:, rain_idx] = np.clip(y_true[:, rain_idx], 0, max_log_rain)

y_pred[:, rain_idx] = np.expm1(y_pred[:, rain_idx])
y_true[:, rain_idx] = np.expm1(y_true[:, rain_idx])
# =====================================================
# 14. EVALUATION METRICS
# =====================================================

results = []

for i, target in enumerate(targets):
    mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
    mse = mean_squared_error(y_true[:, i], y_pred[:, i])
    rmse = np.sqrt(mse)
    r2 = r2_score(y_true[:, i], y_pred[:, i])

    results.append({
        "Target": target,
        "MAE": mae,
        "MSE": mse,
        "RMSE": rmse,
        "R2": r2
    })

results_df = pd.DataFrame(results)

print(results_df)

results_df.to_excel(
    "cnn_lstm_results.xlsx",
    index=False
)


# =====================================================
# 15. TRUE VS PREDICTED PLOTS
# =====================================================

for i, target in enumerate(targets):
    plt.figure(figsize=(12, 4))
    plt.plot(y_true[:, i], label="True", linewidth=1)
    plt.plot(y_pred[:, i], label="Predicted", linewidth=1)
    plt.title(f"True vs Predicted: {target}")
    plt.xlabel("Test Samples")
    plt.ylabel(target)
    plt.legend()
    plt.grid(True)
    plt.show()


# =====================================================
# 16. SAVE PREDICTIONS
# =====================================================

pred_df = pd.DataFrame()

pred_df["Date"] = d_test
pred_df["Station_enc"] = S_test
pred_df["Station"] = le.inverse_transform(S_test.astype(int))

for i, target in enumerate(targets):
    pred_df[f"True_{target}"] = y_true[:, i]
    pred_df[f"Predicted_{target}"] = y_pred[:, i]

pred_df.to_excel(
    "cnn_lstm_predictions.xlsx",
    index=False
)

print("Saved:")
print("cnn_lstm_results.xlsx")
print("cnn_lstm_predictions.xlsx")


# =====================================================
# 17. SAVE MODEL
# =====================================================

#model.save("cnn_lstm_weather_model.keras")

#print("Model saved as cnn_lstm_weather_model.keras")

model.save("cnn_lstm_weather_model_final.keras")
results_df.to_excel("cnn_lstm_results_final.xlsx", index=False)
# Out:
#    Rain_original      Rain
# 0            0.5  0.405465
# 1            0.0  0.000000
# 2           20.4  3.063391
# 3            2.0  1.098612
# 4            0.0  0.000000
#     Station       Date  Temp     RH  Wind      Rain  PRESS  SUNSHINE  Month  \
# 0  HEB00008 2015-01-01   9.7   64.5   3.4  0.405465  899.1       1.6      1
# 1  HEB00008 2015-01-02   6.6   92.0   3.0  0.000000  901.3       5.0      1
# 2  HEB00008 2015-01-03   6.7   99.4   5.3  3.063391  899.2       2.6      1
# 3  HEB00008 2015-01-04   5.1  100.0   4.0  1.098612  897.7       1.0      1
# 4  HEB00008 2015-01-05   6.9   84.9   4.9  0.000000  895.8       8.0      1
#
#    Rain_original
# 0            0.5
# 1            0.0
# 2           20.4
# 3            2.0
# 4            0.0
# Station          0
# Date             0
# Temp             0
# RH               0
# Wind             0
# Rain             0
# PRESS            0
# SUNSHINE         0
# Month            0
# Rain_original    0
# dtype: int64
# Pressure zeros: 0
# Negative rain: 0
# RH > 100: 0
# RH < 0: 0
# Negative sunshine: 0
#                              Date          Temp            RH          Wind  \
# count                       16768  16768.000000  16768.000000  16768.000000
# mean   2019-12-04 19:43:28.969465     20.024738     64.134244      3.230850
# min           2015-01-01 00:00:00     -0.400000      8.000000      0.000000
# 25%           2017-04-19 00:00:00     14.400000     47.300000      2.100000
# 50%           2019-08-08 12:00:00     20.400000     66.000000      2.900000
# 75%           2023-01-08 00:00:00     25.400000     80.800000      3.900000
# max           2025-04-30 00:00:00     39.700000    100.000000     19.000000
# std                           NaN      7.205913     20.359440      1.750385
#
#                Rain         PRESS      SUNSHINE         Month  Rain_original
# count  16768.000000  16768.000000  16768.000000  16768.000000   16768.000000
# mean       0.241641    961.723196      7.552434      6.402851       1.330372
# min        0.000000    882.000000      0.000000      1.000000       0.000000
# 25%        0.000000    917.100000      5.405492      3.000000       0.000000
# 50%        0.000000    950.300000      8.500000      6.000000       0.000000
# 75%        0.000000    999.200000     10.442198      9.000000       0.000000
# max        4.769837   1065.000000     14.700000     12.000000     116.900000
# std        0.726941     53.415701      3.699434      3.478600       6.029002
# Station Encoding:
# HEB00008 : 0
# JEN00001 : 1
# JER00005 : 2
# NAB00003 : 3
# RAM00004 : 4
# Train: (12539, 14)
# Validation: (1814, 14)
# Test: (1818, 14)
# X_train: (12389, 30, 9)
# S_train: (12389,)
# y_train: (12389, 5)
# X_val: (1664, 30, 9)
# X_test: (1668, 30, 9)
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ sequence_input      │ (None, 30, 9)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ station_input       │ (None, 1)         │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_2 (Conv1D)   │ (None, 28, 64)    │      1,792 │ sequence_input[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ station_embedding   │ (None, 1, 4)      │         20 │ station_input[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_2 (LSTM)       │ (None, 64)        │     33,024 │ conv1d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 4)         │          0 │ station_embeddin… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 68)        │          0 │ lstm_2[0][0],     │
# │ (Concatenate)       │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      4,416 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 5)         │        325 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 39,577 (154.60 KB)
#  Trainable params: 39,577 (154.60 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 0.0251 - mae: 0.1143 - val_loss: 0.0159 - val_mae: 0.0878
# Epoch 2/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0163 - mae: 0.0886 - val_loss: 0.0138 - val_mae: 0.0773
# Epoch 3/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0147 - mae: 0.0821 - val_loss: 0.0130 - val_mae: 0.0756
# Epoch 4/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0139 - mae: 0.0785 - val_loss: 0.0131 - val_mae: 0.0768
# Epoch 5/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0133 - mae: 0.0761 - val_loss: 0.0125 - val_mae: 0.0730
# Epoch 6/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0129 - mae: 0.0741 - val_loss: 0.0125 - val_mae: 0.0726
# Epoch 7/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0127 - mae: 0.0728 - val_loss: 0.0125 - val_mae: 0.0724
# Epoch 8/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0125 - mae: 0.0721 - val_loss: 0.0122 - val_mae: 0.0713
# Epoch 9/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0123 - mae: 0.0712 - val_loss: 0.0129 - val_mae: 0.0747
# Epoch 10/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0122 - mae: 0.0705 - val_loss: 0.0128 - val_mae: 0.0749
# Epoch 11/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0121 - mae: 0.0701 - val_loss: 0.0122 - val_mae: 0.0701
# Epoch 12/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0119 - mae: 0.0696 - val_loss: 0.0127 - val_mae: 0.0735
# Epoch 13/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0119 - mae: 0.0691 - val_loss: 0.0123 - val_mae: 0.0702
# Epoch 14/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0118 - mae: 0.0687 - val_loss: 0.0126 - val_mae: 0.0723
# Epoch 15/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0117 - mae: 0.0684 - val_loss: 0.0124 - val_mae: 0.0707
# Epoch 16/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0116 - mae: 0.0680 - val_loss: 0.0124 - val_mae: 0.0686
# Epoch 17/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0115 - mae: 0.0676 - val_loss: 0.0122 - val_mae: 0.0689
# Epoch 18/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0114 - mae: 0.0672 - val_loss: 0.0121 - val_mae: 0.0675
# Epoch 19/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0113 - mae: 0.0668 - val_loss: 0.0119 - val_mae: 0.0648
# Epoch 20/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0113 - mae: 0.0667 - val_loss: 0.0119 - val_mae: 0.0660
# Epoch 21/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0112 - mae: 0.0666 - val_loss: 0.0123 - val_mae: 0.0672
# Epoch 22/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0111 - mae: 0.0661 - val_loss: 0.0122 - val_mae: 0.0667
# Epoch 23/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0109 - mae: 0.0654 - val_loss: 0.0121 - val_mae: 0.0656
# Epoch 24/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0109 - mae: 0.0654 - val_loss: 0.0122 - val_mae: 0.0663
# Epoch 25/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0109 - mae: 0.0653 - val_loss: 0.0122 - val_mae: 0.0664
# Epoch 26/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0108 - mae: 0.0650 - val_loss: 0.0126 - val_mae: 0.0681
# Epoch 27/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0106 - mae: 0.0645 - val_loss: 0.0123 - val_mae: 0.0667
# Epoch 28/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0106 - mae: 0.0648 - val_loss: 0.0127 - val_mae: 0.0684
# Epoch 29/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0105 - mae: 0.0643 - val_loss: 0.0127 - val_mae: 0.0673
# Epoch 30/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0104 - mae: 0.0640 - val_loss: 0.0130 - val_mae: 0.0698
# Epoch 31/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0103 - mae: 0.0637 - val_loss: 0.0133 - val_mae: 0.0700
# Epoch 32/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0103 - mae: 0.0634 - val_loss: 0.0124 - val_mae: 0.0659
# Epoch 33/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0102 - mae: 0.0634 - val_loss: 0.0128 - val_mae: 0.0681
# Epoch 34/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0101 - mae: 0.0628 - val_loss: 0.0126 - val_mae: 0.0657
# Epoch 35/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0099 - mae: 0.0624 - val_loss: 0.0131 - val_mae: 0.0708
# Epoch 36/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0100 - mae: 0.0626 - val_loss: 0.0129 - val_mae: 0.0681
# Epoch 37/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0098 - mae: 0.0621 - val_loss: 0.0129 - val_mae: 0.0672
# Epoch 38/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0097 - mae: 0.0618 - val_loss: 0.0129 - val_mae: 0.0679
# Epoch 39/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0096 - mae: 0.0616 - val_loss: 0.0132 - val_mae: 0.0685
# Epoch 40/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0095 - mae: 0.0614 - val_loss: 0.0135 - val_mae: 0.0705
# Epoch 41/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0095 - mae: 0.0612 - val_loss: 0.0137 - val_mae: 0.0709
# Epoch 42/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0094 - mae: 0.0609 - val_loss: 0.0133 - val_mae: 0.0699
# Epoch 43/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0093 - mae: 0.0605 - val_loss: 0.0133 - val_mae: 0.0678
# Epoch 44/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.0092 - mae: 0.0604 - val_loss: 0.0138 - val_mae: 0.0723
# Epoch 45/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0092 - mae: 0.0601 - val_loss: 0.0136 - val_mae: 0.0694
# Epoch 46/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0090 - mae: 0.0599 - val_loss: 0.0133 - val_mae: 0.0693
# Epoch 47/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.0090 - mae: 0.0598 - val_loss: 0.0138 - val_mae: 0.0705
# Epoch 48/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0088 - mae: 0.0591 - val_loss: 0.0138 - val_mae: 0.0697
# Epoch 49/100
# 388/388 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.0088 - mae: 0.0592 - val_loss: 0.0134 - val_mae: 0.0684
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#      Target       MAE         MSE       RMSE        R2
# 0      Temp  1.477606    3.748779   1.936176  0.923269
# 1        RH  8.617679  136.568937  11.686271  0.633691
# 2      Rain  0.962791   13.754989   3.708772  0.126129
# 3     PRESS  3.143485   15.521347   3.939714  0.994621
# 4  SUNSHINE  1.187252    3.196870   1.787979  0.825502
# Saved:
# cnn_lstm_results.xlsx
# cnn_lstm_predictions.xlsx
